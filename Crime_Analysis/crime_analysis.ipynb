# %% [markdown]
# # Los Angeles Police Department Crime and Arrest Data

# %%
import pandas as pd
import plotnine
import geopandas as gpd

# %% [markdown]
# ## LAPD Arrest Data
#
# Data comes from the Los Angeles Data Catalogue where the county publishes severeral datasets about the city including some LAPD data.
#
# https://data.lacity.org/A-Safe-City/Arrest-Data-from-2010-to-Present/yru6-6re4
#
# ### Data Cleaning Tasks
#
# - Filter to only 2019 data
# - Split latitude and longitude coordinates for mapping

# %%
lapd_arrests = pd.read_csv('data/Arrest_Data_from_2010_to_Present.csv')

# %%
date = lapd_arrests['Arrest Date'].str.split("/",expand=True)

# %%
date.columns = ['month','day','year']
date.head()
# Out:
#   month day  year
# 0    04  07  2020
# 1    04  07  2020
# 2    04  09  2020
# 3    04  03  2020
# 4    04  09  2020

# %%
lapd_arrests.drop(columns=['Arrest Date'],inplace=True)
lapd_arrests.head()
# Out:
#    Report ID    Time  Area ID Area Name  Reporting District  Age Sex Code  \
# 0  200110198  2315.0        1   Central                 185   63        M
# 1  200110199  2300.0        1   Central                 152   68        M
# 2  200110228   200.0        1   Central                 119   44        M
# 3  200110239  1205.0        1   Central                 185   40        F
# 4  200110242   130.0        1   Central                 191   32        M
#
#   Descent Code  Charge Group Code        Charge Group Description  \
# 0            B                NaN                             NaN
# 1            B                8.0                  Other Assaults
# 2            H               24.0  Miscellaneous Other Violations
# 3            H                9.0             Forgery/Counterfeit
# 4            B               24.0  Miscellaneous Other Violations
#
#   Arrest Type Code       Charge                        Charge Description  \
# 0                M  57.305.4LAM                                       NaN
# 1                M     243(A)PC                         BATTERY ON PERSON
# 2                M     602(O)PC                  TRESPASS ON CLOSED LANDS
# 3                M  350(A)(1)PC  POSS < 1,000 ARTICLES W/COUNTERFEIT MARK
# 4                M     602(O)PC                  TRESPASS ON CLOSED LANDS
#
#                                   Address                     Cross Street  \
# 0                                   MAPLE                             18TH
# 1         6TH                          ST  OLIVE                        ST
# 2   00    GATEWAY PLAZA                DR                              NaN
# 3  300 E  12TH                         ST                              NaN
# 4  600 W  WASHINGTON                   BL                              NaN
#
#                Location
# 0  (34.0388, -118.2574)
# 1  (34.0481, -118.2542)
# 2  (34.0551, -118.2323)
# 3  (34.0363, -118.2573)
# 4  (34.0388, -118.2717)

# %%
lapd_arrests = pd.concat([lapd_arrests, date], axis=1)
lapd_arrests.head()
# Out:
#    Report ID    Time  Area ID Area Name  Reporting District  Age Sex Code  \
# 0  200110198  2315.0        1   Central                 185   63        M
# 1  200110199  2300.0        1   Central                 152   68        M
# 2  200110228   200.0        1   Central                 119   44        M
# 3  200110239  1205.0        1   Central                 185   40        F
# 4  200110242   130.0        1   Central                 191   32        M
#
#   Descent Code  Charge Group Code        Charge Group Description  \
# 0            B                NaN                             NaN
# 1            B                8.0                  Other Assaults
# 2            H               24.0  Miscellaneous Other Violations
# 3            H                9.0             Forgery/Counterfeit
# 4            B               24.0  Miscellaneous Other Violations
#
#   Arrest Type Code       Charge                        Charge Description  \
# 0                M  57.305.4LAM                                       NaN
# 1                M     243(A)PC                         BATTERY ON PERSON
# 2                M     602(O)PC                  TRESPASS ON CLOSED LANDS
# 3                M  350(A)(1)PC  POSS < 1,000 ARTICLES W/COUNTERFEIT MARK
# 4                M     602(O)PC                  TRESPASS ON CLOSED LANDS
#
#                                   Address                     Cross Street  \
# 0                                   MAPLE                             18TH
# 1         6TH                          ST  OLIVE                        ST
# 2   00    GATEWAY PLAZA                DR                              NaN
# 3  300 E  12TH                         ST                              NaN
# 4  600 W  WASHINGTON                   BL                              NaN
#
#                Location month day  year
# 0  (34.0388, -118.2574)    04  07  2020
# 1  (34.0481, -118.2542)    04  07  2020
# 2  (34.0551, -118.2323)    04  09  2020
# 3  (34.0363, -118.2573)    04  03  2020
# 4  (34.0388, -118.2717)    04  09  2020

# %%
lapd_arrests = lapd_arrests[lapd_arrests['year'] == '2019']
lapd_arrests.head()
# Out:
#      Report ID    Time  Area ID  Area Name  Reporting District  Age Sex Code  \
# 237    5564552  1300.0        7   Wilshire                 759   27        F
# 625    5805106  2100.0        3  Southwest                 328   25        M
# 682  190127182  1000.0        1    Central                 119   30        M
# 683  191119468  1500.0       11  Northeast                1102   39        F
# 708    5511899  1700.0       19    Mission                1998   33        M
#
#     Descent Code  Charge Group Code Charge Group Description Arrest Type Code  \
# 237            H               16.0       Narcotic Drug Laws                F
# 625            B                5.0                 Burglary                F
# 682            B               20.0       Disorderly Conduct                M
# 683            O                NaN                      NaN                M
# 708            B                4.0       Aggravated Assault                F
#
#           Charge                        Charge Description  \
# 237      11366HS    MAINTAIN PLACE TO SELL CONTROLLED SUBS
# 625        459PC                                  BURGLARY
# 682  640(D)(3)PC   URINTATIN/DEFECATING ON TRAIN OR SYSTEM
# 683      459.2PC                                       NaN
# 708   273.5(A)PC  CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
#
#                                      Address Cross Street  \
# 237  4000 W  PICO                         BL          NaN
# 625                                     32ND       HOOVER
# 682   800 N  ALAMEDA                      ST          NaN
# 683  2900    LOS FELIZ                    BL          NaN
# 708  8200    HAZELTINE                    AV          NaN
#
#                  Location month day  year
# 237  (34.0495, -118.3215)    03  05  2019
# 625  (34.0255, -118.2839)    11  21  2019
# 682  (34.0563, -118.2374)    10  03  2019
# 683  (34.1367, -118.2713)    11  13  2019
# 708  (34.2202, -118.4399)    01  03  2019

# %%
coords = lapd_arrests['Location'].str.split(",",expand=True)
coords.head()
# Out:
#             0            1
# 237  (34.0495   -118.3215)
# 625  (34.0255   -118.2839)
# 682  (34.0563   -118.2374)
# 683  (34.1367   -118.2713)
# 708  (34.2202   -118.4399)

# %%
coords.columns = ['latitude','longitude']
coords.head()
# Out:
#      latitude    longitude
# 237  (34.0495   -118.3215)
# 625  (34.0255   -118.2839)
# 682  (34.0563   -118.2374)
# 683  (34.1367   -118.2713)
# 708  (34.2202   -118.4399)

# %%
coords['latitude'] = coords['latitude'].str.replace('(','', regex=False)
coords['longitude'] = coords['longitude'].str.replace(')','', regex=False)
coords.head()
# Out:
#     latitude   longitude
# 237  34.0495   -118.3215
# 625  34.0255   -118.2839
# 682  34.0563   -118.2374
# 683  34.1367   -118.2713
# 708  34.2202   -118.4399

# %%
lapd_arrests.drop(columns=['Location'],inplace=True)
lapd_arrests = pd.concat([lapd_arrests, coords], axis=1)
lapd_arrests.head()
# Out:
#      Report ID    Time  Area ID  Area Name  Reporting District  Age Sex Code  \
# 237    5564552  1300.0        7   Wilshire                 759   27        F
# 625    5805106  2100.0        3  Southwest                 328   25        M
# 682  190127182  1000.0        1    Central                 119   30        M
# 683  191119468  1500.0       11  Northeast                1102   39        F
# 708    5511899  1700.0       19    Mission                1998   33        M
#
#     Descent Code  Charge Group Code Charge Group Description Arrest Type Code  \
# 237            H               16.0       Narcotic Drug Laws                F
# 625            B                5.0                 Burglary                F
# 682            B               20.0       Disorderly Conduct                M
# 683            O                NaN                      NaN                M
# 708            B                4.0       Aggravated Assault                F
#
#           Charge                        Charge Description  \
# 237      11366HS    MAINTAIN PLACE TO SELL CONTROLLED SUBS
# 625        459PC                                  BURGLARY
# 682  640(D)(3)PC   URINTATIN/DEFECATING ON TRAIN OR SYSTEM
# 683      459.2PC                                       NaN
# 708   273.5(A)PC  CORPORAL INJURY ON SPOUSE/COHABITANT/ETC
#
#                                      Address Cross Street month day  year  \
# 237  4000 W  PICO                         BL          NaN    03  05  2019
# 625                                     32ND       HOOVER    11  21  2019
# 682   800 N  ALAMEDA                      ST          NaN    10  03  2019
# 683  2900    LOS FELIZ                    BL          NaN    11  13  2019
# 708  8200    HAZELTINE                    AV          NaN    01  03  2019
#
#     latitude   longitude
# 237  34.0495   -118.3215
# 625  34.0255   -118.2839
# 682  34.0563   -118.2374
# 683  34.1367   -118.2713
# 708  34.2202   -118.4399

# %%
lapd_arrests['Charge Description'].fillna("Missing Charge Description", inplace = True)

# %% [markdown]
# ## LAPD Filed Crime Reports
#
# This data also comes from the LA county data catalogue and can be found here https://data.lacity.org/A-Safe-City/Crime-Data-from-2010-to-2019/63jg-8b9z
#
# ### Data Cleaning Tasks
#
# - Filter to only 2019 data

# %%
lapd = pd.read_csv('data/lapd_crime_2010_to_2019.csv')
lapd.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Status  \
# 0                           VIOLATION OF COURT ORDER  ...     AA
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 2                          OTHER MISCELLANEOUS CRIME  ...     IC
# 3                           VIOLATION OF COURT ORDER  ...     IC
# 4                                    RAPE, ATTEMPTED  ...     IC
#
#     Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0  Adult Arrest    900.0      NaN       NaN      NaN
# 1   Invest Cont    740.0      NaN       NaN      NaN
# 2   Invest Cont    946.0      NaN       NaN      NaN
# 3   Invest Cont    900.0    998.0       NaN      NaN
# 4   Invest Cont    122.0      NaN       NaN      NaN
#
#                                   LOCATION                     Cross Street  \
# 0   300 E  GAGE                         AV                              NaN
# 1          SEPULVEDA                    BL  MANCHESTER                   AV
# 2  1300 E  21ST                         ST                              NaN
# 3          CAHUENGA                     BL  HOLLYWOOD                    BL
# 4          8TH                          ST  SAN PEDRO                    ST
#
#        LAT       LON
# 0  33.9825 -118.2695
# 1  33.9599 -118.3962
# 2  34.0224 -118.2524
# 3  34.1016 -118.3295
# 4  34.0387 -118.2488
#
# [5 rows x 28 columns]

# %%
lapd['date'] = lapd['DATE OCC'].str.slice(start=0, stop=10)
lapd.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ...   Status Desc  \
# 0                           VIOLATION OF COURT ORDER  ...  Adult Arrest
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...   Invest Cont
# 2                          OTHER MISCELLANEOUS CRIME  ...   Invest Cont
# 3                           VIOLATION OF COURT ORDER  ...   Invest Cont
# 4                                    RAPE, ATTEMPTED  ...   Invest Cont
#
#    Crm Cd 1 Crm Cd 2 Crm Cd 3  Crm Cd 4  \
# 0     900.0      NaN      NaN       NaN
# 1     740.0      NaN      NaN       NaN
# 2     946.0      NaN      NaN       NaN
# 3     900.0    998.0      NaN       NaN
# 4     122.0      NaN      NaN       NaN
#
#                                   LOCATION                     Cross Street  \
# 0   300 E  GAGE                         AV                              NaN
# 1          SEPULVEDA                    BL  MANCHESTER                   AV
# 2  1300 E  21ST                         ST                              NaN
# 3          CAHUENGA                     BL  HOLLYWOOD                    BL
# 4          8TH                          ST  SAN PEDRO                    ST
#
#        LAT       LON        date
# 0  33.9825 -118.2695  02/20/2010
# 1  33.9599 -118.3962  09/12/2010
# 2  34.0224 -118.2524  08/09/2010
# 3  34.1016 -118.3295  01/05/2010
# 4  34.0387 -118.2488  01/02/2010
#
# [5 rows x 29 columns]

# %%
date = lapd['date'].str.split("/",expand=True)
date.head()
# Out:
#     0   1     2
# 0  02  20  2010
# 1  09  12  2010
# 2  08  09  2010
# 3  01  05  2010
# 4  01  02  2010

# %%
date.columns = ['month','day','year']
date.head()
# Out:
#   month day  year
# 0    02  20  2010
# 1    09  12  2010
# 2    08  09  2010
# 3    01  05  2010
# 4    01  02  2010

# %%
lapd.drop(columns=['date'],inplace=True)

# %%
lapd = pd.concat([lapd, date], axis=1)
lapd.head()
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA   \
# 0    1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350     13
# 1   11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45     14
# 2   70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515     13
# 3   90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150      6
# 4  100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100      1
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0     Newton         1385         2     900
# 1    Pacific         1485         2     740
# 2     Newton         1324         2     946
# 3  Hollywood          646         2     900
# 4    Central          176         1     122
#
#                                          Crm Cd Desc  ... Crm Cd 2  Crm Cd 3  \
# 0                           VIOLATION OF COURT ORDER  ...      NaN       NaN
# 1  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...      NaN       NaN
# 2                          OTHER MISCELLANEOUS CRIME  ...      NaN       NaN
# 3                           VIOLATION OF COURT ORDER  ...    998.0       NaN
# 4                                    RAPE, ATTEMPTED  ...      NaN       NaN
#
#   Crm Cd 4                                 LOCATION  \
# 0      NaN   300 E  GAGE                         AV
# 1      NaN          SEPULVEDA                    BL
# 2      NaN  1300 E  21ST                         ST
# 3      NaN          CAHUENGA                     BL
# 4      NaN          8TH                          ST
#
#                       Cross Street      LAT       LON month day  year
# 0                              NaN  33.9825 -118.2695    02  20  2010
# 1  MANCHESTER                   AV  33.9599 -118.3962    09  12  2010
# 2                              NaN  34.0224 -118.2524    08  09  2010
# 3  HOLLYWOOD                    BL  34.1016 -118.3295    01  05  2010
# 4  SAN PEDRO                    ST  34.0387 -118.2488    01  02  2010
#
# [5 rows x 31 columns]

# %%
lapd = lapd[lapd['year'] == '2019']
lapd.head()
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1842149  191223057  09/19/2019 12:00:00 AM  09/19/2019 12:00:00 AM       300
# 1842849  190712477  06/20/2019 12:00:00 AM  06/20/2019 12:00:00 AM       600
# 1842877  191323722  12/12/2019 12:00:00 AM  12/11/2019 12:00:00 AM      1800
# 1843272  190905510  01/31/2019 12:00:00 AM  01/31/2019 12:00:00 AM       900
# 1843665  191304702  01/14/2019 12:00:00 AM  01/14/2019 12:00:00 AM       800
#
#          AREA     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd       Crm Cd Desc  \
# 1842149     12  77th Street         1208         1     510  VEHICLE - STOLEN
# 1842849      7     Wilshire          765         1     510  VEHICLE - STOLEN
# 1842877     13       Newton         1345         1     510  VEHICLE - STOLEN
# 1843272      9     Van Nuys          935         1     510  VEHICLE - STOLEN
# 1843665     13       Newton         1321         1     510  VEHICLE - STOLEN
#
#          ... Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 1842149  ...      NaN       NaN      NaN
# 1842849  ...      NaN       NaN      NaN
# 1842877  ...      NaN       NaN      NaN
# 1843272  ...      NaN       NaN      NaN
# 1843665  ...      NaN       NaN      NaN
#
#                                         LOCATION  \
# 1842149                                   VERNON
# 1842849  4500 W  PICO                         BL
# 1842877  1300 E  33RD                         ST
# 1843272                                   SYLVAN
# 1843665                                     21ST
#
#                             Cross Street      LAT       LON month day  year
# 1842149                           HOOVER  34.0037 -118.2871    09  19  2019
# 1842849                              NaN  34.0485 -118.3335    06  20  2019
# 1842877                              NaN  34.0133 -118.2522    12  11  2019
# 1843272                           SYLMAR  34.1847 -118.4465    01  31  2019
# 1843665  MAIN                         ST  34.0289 -118.2661    01  14  2019
#
# [5 rows x 31 columns]

# %%
lapd.rename(columns={"LAT": "latitude", "LON": "longitude"}, inplace=True)
lapd.head()
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 1842149  191223057  09/19/2019 12:00:00 AM  09/19/2019 12:00:00 AM       300
# 1842849  190712477  06/20/2019 12:00:00 AM  06/20/2019 12:00:00 AM       600
# 1842877  191323722  12/12/2019 12:00:00 AM  12/11/2019 12:00:00 AM      1800
# 1843272  190905510  01/31/2019 12:00:00 AM  01/31/2019 12:00:00 AM       900
# 1843665  191304702  01/14/2019 12:00:00 AM  01/14/2019 12:00:00 AM       800
#
#          AREA     AREA NAME  Rpt Dist No  Part 1-2  Crm Cd       Crm Cd Desc  \
# 1842149     12  77th Street         1208         1     510  VEHICLE - STOLEN
# 1842849      7     Wilshire          765         1     510  VEHICLE - STOLEN
# 1842877     13       Newton         1345         1     510  VEHICLE - STOLEN
# 1843272      9     Van Nuys          935         1     510  VEHICLE - STOLEN
# 1843665     13       Newton         1321         1     510  VEHICLE - STOLEN
#
#          ... Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 1842149  ...      NaN       NaN      NaN
# 1842849  ...      NaN       NaN      NaN
# 1842877  ...      NaN       NaN      NaN
# 1843272  ...      NaN       NaN      NaN
# 1843665  ...      NaN       NaN      NaN
#
#                                         LOCATION  \
# 1842149                                   VERNON
# 1842849  4500 W  PICO                         BL
# 1842877  1300 E  33RD                         ST
# 1843272                                   SYLVAN
# 1843665                                     21ST
#
#                             Cross Street latitude  longitude month day  year
# 1842149                           HOOVER  34.0037  -118.2871    09  19  2019
# 1842849                              NaN  34.0485  -118.3335    06  20  2019
# 1842877                              NaN  34.0133  -118.2522    12  11  2019
# 1843272                           SYLMAR  34.1847  -118.4465    01  31  2019
# 1843665  MAIN                         ST  34.0289  -118.2661    01  14  2019
#
# [5 rows x 31 columns]

# %% [markdown]
# ## LASD Filed Crime Reports
#
# This data also comes directly from the los angeles sheriffs department located here https://lasd.org/transparency/preliminarycrimedata/
#
# This comes from
#
# ### Data Cleaning Tasks
#
# - Filter to only 2019 data
